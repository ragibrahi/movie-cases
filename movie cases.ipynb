# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\skrag'

# %%
os.chdir('E://01_2019_DS//Datasets//')
print(os.getcwd())
# Out:
# E:\01_2019_DS\Datasets

# %%
movies =pd.read_csv('Movie-Ratings.csv')

# %%
len(movies)
# Out:
# 562

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
#lets fix the indexes in the column

# %%
movies.colums=[...]
# Out:
# C:\Users\skrag\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
movies.columns=[...]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-aa33f34817a1> in <module>
# ----> 1 movies.columns=[...]
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5078         try:
#    5079             object.__getattribute__(self, name)
# -> 5080             return object.__setattr__(self, name, value)
#    5081         except AttributeError:
#    5082             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     636
#     637     def _set_axis(self, axis, labels):
# --> 638         self._data.set_axis(axis, labels)
#     639         self._clear_item_cache()
#     640
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     153             raise ValueError(
#     154                 'Length mismatch: Expected axis has {old} elements, new '
# --> 155                 'values have {new} elements'.format(old=old_len, new=new_len))
#     156
#     157         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 6 elements, new values have 1 elements

# %%
movies.columns = ['Film','Genre',u'CriticRating',u'AudienceRating',u'BudgetMillions',u'Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 562 entries, 0 to 561
# Data columns (total 6 columns):
# Film              562 non-null object
# Genre             562 non-null object
# CriticRating      562 non-null int64
# AudienceRating    562 non-null int64
# BudgetMillions    562 non-null int64
# Year              562 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 26.4+ KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    562.000000      562.000000      562.000000   562.000000
# mean      47.403915       58.830961       50.104982  2009.145907
# std       26.392394       16.827792       48.638482     1.361578
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
#ntc year,ds it make sence,v dnt want treat yr as num but cat

# %%
#convert it into catergory var

# %%
movies.Film=movies.Film.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 562 entries, 0 to 561
# Data columns (total 6 columns):
# Film              562 non-null category
# Genre             562 non-null object
# CriticRating      562 non-null int64
# AudienceRating    562 non-null int64
# BudgetMillions    562 non-null int64
# Year              562 non-null int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 47.5+ KB

# %%
movies.Genre=movies.Genre.astype('category')

# %%
movies.Year=movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 562 entries, 0 to 561
# Data columns (total 6 columns):
# Film              562 non-null category
# Genre             562 non-null category
# CriticRating      562 non-null int64
# AudienceRating    562 non-null int64
# BudgetMillions    562 non-null int64
# Year              562 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.4 KB

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    562.000000      562.000000      562.000000
# mean      47.403915       58.830961       50.104982
# std       26.392394       16.827792       48.638482
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
from matplotlib import pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
j= sns.jointplot(data=movies,x='CriticRating',y='AudienceRating')

# %%
j= sns.jointplot(data=movies,x='CriticRating',y='AudienceRating',kind='hex')

# %%
#here we join the plots

# %%
j=sns.jointplot(data=movies,x='CriticRating',y='AudienceRating')
j= sns.jointplot(data=movies,x='CriticRating',y='AudienceRating',kind='hex')

# %%
    #histograms

# %%
m1=sns.distplot(movies.AudienceRating)

# %%
m1=sns.distplot(movies.AudienceRating,bins=15)

# %%
m1=sns.distplot(movies.CriticRating,bins=15)

# %%
n1=sns.distplot(movies.AudienceRating,bins=15)

# %%
m1=sns.distplot(movies.AudienceRating)
m1=sns.distplot(movies.AudienceRating,bins=15)
m1=sns.distplot(movies.CriticRating,bins=15)
n1=sns.distplot(movies.AudienceRating,bins=15)

# %%
#this is wo  seaborn,ntc the x axis 
#ntc AR is normallly distrubuted
#humans r normal
#they are emoytionally attachd from a psychology
#it is natural
#these are theories or hypothesis

# %%
n2 = plt.hist(movies.CriticRating,bins=15) 
#slightly uniform distributed

# %%
# Stacked histograms 
plt.hist(movies.BudgetMillions) 
plt.show()

# %%
FilterDrama = movies.Genre=='Drama'

# %%
#FilterDrama
movies[FilterDrama]
movies[FilterDrama].BudgetMillions
plt.hist(movies[movies.Genre=='Drama'].BudgetMillions) 
plt.show()

# %%
plt.hist(movies[movies.Genre=='Action'].BudgetMillions) 
plt.show()

# %%
plt.hist(movies[movies.Genre=='Drama'].BudgetMillions) 
plt.hist(movies[movies.Genre=='Action'].BudgetMillions) 
plt.show()

# %%
plt.hist(movies[movies.Genre=='Drama'].BudgetMillions) 
plt.hist(movies[movies.Genre=='Action'].BudgetMillions) 
plt.hist(movies[movies.Genre=='Thriller'].BudgetMillions) 
plt.show()

# %%
#ntc they all hv diff bins

# %%
plt.hist(movies[movies.Genre=='Action'].BudgetMillions) 
plt.hist(movies[movies.Genre=='Drama'].BudgetMillions) 
plt.hist(movies[movies.Genre=='Thriller'].BudgetMillions) 
plt.show()

# %%
plt.hist(movies[movies.Genre=='Action'].BudgetMillions)
# Out:
# (array([29., 43., 24., 14., 13., 14., 11.,  3.,  2.,  1.]),
#  array([  0.,  30.,  60.,  90., 120., 150., 180., 210., 240., 270., 300.]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(movies[movies.Genre=='Action'].BudgetMillions,bins=15) 
plt.hist(movies[movies.Genre=='Drama'].BudgetMillions,bins=15) 
plt.hist(movies[movies.Genre=='Thriller'].BudgetMillions,bins=15) 
plt.show()

# %%
plt.hist([movies[movies.Genre=='Action'].BudgetMillions,movies[movies.Genre=='Drama'].BudgetMillions],bins=15,stacked=True)
# Out:
# ([array([ 9., 39., 24., 13., 16.,  9.,  8., 14.,  5.,  4.,  8.,  2.,  2.,
#           0.,  1.]),
#   array([48., 80., 35., 19., 18., 10.,  8., 15.,  5.,  4.,  8.,  2.,  2.,
#           0.,  1.])],
#  array([  0.,  20.,  40.,  60.,  80., 100., 120., 140., 160., 180., 200.,
#         220., 240., 260., 280., 300.]),
#  <a list of 2 Lists of Patches objects>)

# %%
plt.hist([movies[movies.Genre=='Action'].BudgetMillions,movies[movies.Genre=='Drama'].BudgetMillions],bins=15,stacked=True)

plt.show()

# %%
plt.hist([movies[movies.Genre=='Action'].BudgetMillions,
movies[movies.Genre=='Drama'].BudgetMillions, movies[movies.Genre=='Thriller'].BudgetMillions], bins=15,stacked=True)
# Out:
# ([array([ 9., 39., 24., 13., 16.,  9.,  8., 14.,  5.,  4.,  8.,  2.,  2.,
#           0.,  1.]),
#   array([48., 80., 35., 19., 18., 10.,  8., 15.,  5.,  4.,  8.,  2.,  2.,
#           0.,  1.]),
#   array([52., 94., 39., 24., 20., 14.,  9., 16.,  5.,  5.,  8.,  2.,  2.,
#           0.,  1.])],
#  array([  0.,  20.,  40.,  60.,  80., 100., 120., 140., 160., 180., 200.,
#         220., 240., 260., 280., 300.]),
#  <a list of 3 Lists of Patches objects>)

# %%
plt.hist([movies[movies.Genre=='Action'].BudgetMillions,
movies[movies.Genre=='Drama'].BudgetMillions, movies[movies.Genre=='Thriller'].BudgetMillions], bins=15,stacked=True)

plt.show()

# %%
plt.hist([movies[movies.Genre=='Action'].BudgetMillions,
movies[movies.Genre=='Drama'].BudgetMillions,movies[movies.Genre=='Thriller'].BudgetMillions,movies[movies.Genre=='Comedy'].BudgetMillions],bins=15,stacked=True)
plt.show()

# %%
for gen in movies.Genre.cat.categories: 
    print (gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
list1 = []

for gen in movies.Genre.cat.categories: 
    list1.append(movies[movies.Genre==gen].BudgetMillions)
print(list1) #prints multiple Series
# Out:
# [2       20
# 5      200
# 15      35
# 29      20
# 30      20
# 33     237
# 36      45
# 39      45
# 40      70
# 45     150
# 49      68
# 52      17
# 58     140
# 60      85
# 63      40
# 66     125
# 67      25
# 69      40
# 70      90
# 73      30
# 76     163
# 77      13
# 81      25
# 83      20
# 86      45
# 94      30
# 98      33
# 101     75
# 102     30
# 106     45
#       ...
# 433    138
# 435     50
# 439     40
# 441     80
# 443    150
# 448     25
# 451     40
# 454    145
# 458    100
# 472    150
# 473      6
# 474      0
# 477    100
# 479     75
# 493    150
# 495     35
# 499    150
# 500    195
# 501    210
# 502     30
# 504    170
# 513     35
# 515     95
# 530     75
# 532     25
# 533    130
# 544     35
# 548    150
# 549    160
# 560     24
# Name: BudgetMillions, Length: 154, dtype: int64, 1      105
# 3       18
# 19     200
# 21      45
# 24      40
# 32      78
# 46      20
# 65      38
# 68     140
# 130     73
# 165     12
# 166    125
# 167    250
# 168    150
# 176     36
# 178    150
# 192     70
# 193     60
# 241     60
# 272     37
# 341     19
# 363     70
# 386    130
# 401    155
# 459     59
# 463     25
# 506     38
# 542    100
# 550     60
# Name: BudgetMillions, dtype: int64, 0       8
# 4      20
# 6      30
# 8      28
# 9       8
# 14     19
# 17     10
# 22     15
# 31     40
# 34     21
# 35     70
# 37     20
# 38     20
# 41     20
# 43     80
# 44      4
# 48     61
# 50     30
# 51     33
# 54     42
# 57     37
# 61     10
# 64      6
# 71     70
# 75     60
# 79      7
# 80      6
# 82     55
# 85     21
# 87      7
#        ..
# 455    45
# 456    20
# 460    40
# 468    75
# 469    25
# 476    19
# 485    38
# 496    48
# 497    75
# 505    90
# 518    19
# 519    52
# 521    20
# 528    35
# 535    50
# 537    35
# 538    35
# 539    20
# 540    15
# 541     0
# 545    20
# 546    90
# 551    70
# 552    80
# 553    20
# 554    80
# 555    22
# 556    50
# 557    18
# 561    80
# Name: BudgetMillions, Length: 172, dtype: int64, 10      30
# 11      20
# 13       7
# 18       8
# 23      20
# 26       8
# 27      30
# 47      13
# 53      26
# 55       2
# 56      55
# 62      55
# 74      15
# 84      25
# 96      37
# 99      25
# 112     60
# 116     21
# 117      5
# 119     31
# 120     40
# 128      1
# 131     24
# 132     21
# 151     33
# 158     16
# 171      7
# 195     15
# 199     35
# 213     10
#       ...
# 437     13
# 442     20
# 444      2
# 445     20
# 446     40
# 450     65
# 457     40
# 466     45
# 467     11
# 470     60
# 480     39
# 482     32
# 483     68
# 484     50
# 487      0
# 488      4
# 489    150
# 490     16
# 492     25
# 509     20
# 510     10
# 512      2
# 517     25
# 525     26
# 529     70
# 531     66
# 534     38
# 536     21
# 543     15
# 547      2
# Name: BudgetMillions, Length: 101, dtype: int64, 7      32
# 12     35
# 20     40
# 28      5
# 59     26
# 88     10
# 97     25
# 100    30
# 103    50
# 109    20
# 126    40
# 135    19
# 137    30
# 160    20
# 161    15
# 175    10
# 194     2
# 246    35
# 259    25
# 285    20
# 286    30
# 292     1
# 293     3
# 294     5
# 311    18
# 315    12
# 321    42
# 322     4
# 332    10
# 333    11
# 335    40
# 343    25
# 349     8
# 355    13
# 373    50
# 404    20
# 414    12
# 416    40
# 426     5
# 429    15
# 453    18
# 461    40
# 462    37
# 464    16
# 465    25
# 475     9
# 478    38
# 486    16
# 522    10
# Name: BudgetMillions, dtype: int64, 16      45
# 42      17
# 78      50
# 108     60
# 136     35
# 201      0
# 208     80
# 244     17
# 250     20
# 255     40
# 266     56
# 284     15
# 290     30
# 354     35
# 507     37
# 508    110
# 511     15
# 524     16
# 526      5
# 527      2
# 558     24
# Name: BudgetMillions, dtype: int64, 25     100
# 72      60
# 95      20
# 105     15
# 179    150
# 180     60
# 189     40
# 225     27
# 237      4
# 243     25
# 253     20
# 261     20
# 263    130
# 267     70
# 282     85
# 358     32
# 385     51
# 389     20
# 394    110
# 406    185
# 407    100
# 408     20
# 419     90
# 424     48
# 432     13
# 471     15
# 481    100
# 491     35
# 494     21
# 498     22
# 503     35
# 514     30
# 516     35
# 520     75
# 523     40
# 559     65
# Name: BudgetMillions, dtype: int64]

# %%
h = plt.hist(list1)

# %%
h = plt.hist(list1,bins=30)

# %%
h = plt.hist(list1,bins=30, stacked=True)

# %%
h = plt.hist(list1,bins=30, stacked=True,rwidth=1) 
#removes the gaps btw bars

# %%
mylabels =list()

# %%
for gen in movies.Genre.cat.categories: 
    mylabels.append(gen)
h = plt.hist(list1,bins=30, stacked=True,rwidth=1,label=mylabels) 

plt.legend()
plt.show()

# %%
# KDE plot

# visualize AR vs CR 
#this is first method

# %%
vis1 = sns.lmplot(data=movies,x='CriticRating',y='AudienceRating',
fit_reg=False,hue='Genre',size=7,aspect=1)

# %%
# btr way is kde plot

# %%
k1 =  sns.kdeplot(movies.CriticRating,movies.AudienceRating)

# %%
# this shows where the most density is
# and how the density is distributed from the chart
# and as v mv away from the kernel or center
# density is getting lower

# %%
k1 = sns.kdeplot(movies.CriticRating,movies.AudienceRating, shade=True)

# %%
k1 = sns.kdeplot(movies.CriticRating,movies.AudienceRating, shade=True,shade_lowest=False)
#shows the grid

# %%
k1 = sns.kdeplot(movies.CriticRating,movies.AudienceRating, shade=True,shade_lowest=False, cmap='Reds')
#shows the color

# %%
# subplots

k1 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRating)

# %%
 #Does the BinMills affect the AR
#slice it at 20M and ntc the AR is apprx 50

#as v mv to the higher Budget AR narrows down also

# %%
sns.set_style("dark")

# %%
k1 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRating)

# %%
sns.set_style("dark")
k2 = sns.kdeplot(movies.BudgetMillions,movies.CriticRating)

# %%
#this shows CR is most concentrated btw 20 and 40

# %%
#subplot
 
f, ax = plt.subplots(1,2)
#gvs 1 row 2 cols
f, ax = plt.subplots(1,3) 
#gvs 1 row 3 cols
f, ax = plt.subplots(1,2) 
#gvs 1 row 2 cols
f, ax = plt.subplots(1,2, figsize=(12,6))
f, ax = plt.subplots(1,2, figsize=(12,6))
k1 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRating) 
k2 = sns.kdeplot(movies.BudgetMillions,movies.CriticRating)

# %%
k1 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRating) 
k2 = sns.kdeplot(movies.BudgetMillions,movies.CriticRating)

# %%
#subplot
 
f, ax = plt.subplots(1,2)
#gvs 1 row 2 cols
f, ax = plt.subplots(1,3) 
#gvs 1 row 3 cols
f, ax = plt.subplots(1,2) 
#gvs 1 row 2 cols
f, ax = plt.subplots(1,2, figsize=(12,6))
f, ax = plt.subplots(1,2, figsize=(12,6))
k1 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRating) 
k2 = sns.kdeplot(movies.BudgetMillions,movies.CriticRating) 
#tried for combinig both

# %%
#they r both printed on 1

# %%
f, axes = plt.subplots(1,2, figsize=(12,6))

k1 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRating,ax=axes[0])
k2 = sns.kdeplot(movies.BudgetMillions,movies.CriticRating,ax=axes[1])

# %%
#ViolinPlots

z = sns.violinplot(data=movies,x='Genre',y='CriticRating')
z = sns.boxplot(data=movies,x='Genre',y='CriticRating')
z = sns.violinplot(data=movies,x='Genre',y='CriticRating') 
z = sns.boxplot(data=movies,x='Genre',y='CriticRating')

# %%
#Facet Grids r created based on rules unlike subplots 
#where v manually create em

# %%
vis1 = sns.lmplot(data=movies,x='CriticRating',y='AudienceRating',
fit_reg=False, hue='Genre',size=6, aspect=1) 
#this is slightly cumbersome chart

# %%
#First create a FG
g = sns.FacetGrid(movies,row='Genre',hue='Genre')

# %%
g = sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')

# %%
plt.scatter(movies.CriticRating,movies.AudienceRating)

# %%
#now v want to map the scatter plot onto the FG

g = sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre') 
g.map(plt.scatter,'CriticRating','AudienceRating')

# %%
g = sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
g.map(plt.hist,'BudgetMillions')

# %%
g = sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre') 
kws = dict(s=50,linewidth=4.5,edgecolor='black')
g.map(plt.scatter,'CriticRating','AudienceRating',**kws)

# %%
#here v analyze from left to right
#how did the relationship btw AR evolve over the years 
#v can observe sm trends

# %%
g = sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre') 
kws = dict(s=50,linewidth=0.5,edgecolor='black') 
g.map(plt.scatter,'CriticRating','AudienceRating',**kws)

# %%
g.set(xlim=(0,100),ylim=(0,100))
#ntc now all the yaxis is from 0 to 100

# %%
g = sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
kws = dict(s=50,linewidth=0.5,edgecolor='black') 
g.map(plt.scatter,'CriticRating','AudienceRating',**kws)
g.set(xlim=(0,100),ylim=(0,100))
#ntc now all the yaxis is from 0 to 100 
for ax in g.axes.flat:
    ax.plot((20,60),(20,60))

# %%
for ax in g.axes.flat:
    ax.plot((20,60),(20,60))

# %%
g = sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre') 
kws = dict(s=50,linewidth=0.5,edgecolor='black') 
g.map(plt.scatter,'CriticRating','AudienceRating',**kws)
g.set(xlim=(0,100),ylim=(0,100)) 
#ntc now all the yaxis is from 0 to 100 
for ax in g.axes.flat:
    ax.plot((0,100),(0,100),c="gray",ls="--")

# %%
for ax in g.axes.flat:
    ax.plot((0,100),(0,100),c="gray",ls="--")

# %%
#ntc now for Genre = action and year = 2009, AR was higher than CR
# and the oppsite is for Genre=Thriller year=2011, Critics gv higher rating 
# than audience

# %%
g = sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
kws = dict(s=50,linewidth=0.5,edgecolor='black') 
g.map(plt.scatter,'CriticRating','AudienceRating',**kws)
g.set(xlim=(0,100),ylim=(0,100)) 
#ntc now all the yaxis is from 0 to 100

# %%
g = sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
kws = dict(s=50,linewidth=0.5,edgecolor='black') 
g.map(plt.scatter,'CriticRating','AudienceRating',**kws)
g.set(xlim=(0,100),ylim=(0,100)) 
for ax in g.axes.flat:
    ax.plot((0,100),(0,100),c="gray",ls="--") 
g.add_legend()

# %%
#Finishing touches 
list1 = []
for gen in movies.Genre.cat.categories: 
    list1.append(movies[movies.Genre==gen].BudgetMillions) 
    mylabels.append(gen)
sns.set_style("whitegrid")

h = plt.hist(list1,bins=30, stacked=True,rwidth=1,label=mylabels) 
plt.legend()
plt.show()

# %%
list1 = []

for gen in movies.Genre.cat.categories: 
    list1.append(movies[movies.Genre==gen].BudgetMillions) 
    mylabels.append(gen)
sns.set_style("whitegrid") 
fig, ax = plt.subplots()
fig.set_size_inches(11.7,8.24) #size of A4 paper

h = plt.hist(list1,bins=30, stacked=True,rwidth=1,label=mylabels) 
plt.legend()
plt.show()

# %%
list1 = []

for gen in movies.Genre.cat.categories: 
    list1.append(movies[movies.Genre==gen].BudgetMillions) 
    mylabels.append(gen)
sns.set_style("whitegrid") 
fig, ax = plt.subplots()
fig.set_size_inches(11.7,8.24) #size of A4 paper

h = plt.hist(list1,bins=30, stacked=True,rwidth=1,label=mylabels) 
plt.title("Movie Budget Distribution",fontsize=35, color="DarkBlue", fontname="Console")

plt.legend() 
plt.show()

# %%
list1 = []

for gen in movies.Genre.cat.categories: 
    list1.append(movies[movies.Genre==gen].BudgetMillions) 
    mylabels.append(gen)
sns.set_style("whitegrid") 
fig, ax = plt.subplots()
fig.set_size_inches(11.7,8.24) #size of A4 paper

h = plt.hist(list1,bins=30, stacked=True,rwidth=1,label=mylabels)

plt.title("Movie Budget Distribution",fontsize=35, color="DarkBlue", fontname="Console") 
plt.ylabel("Number of Movies",fontsize=25,color="Red") 
plt.xlabel("Budget",fontsize=25,color="Green")
plt.legend() 
plt.show()

# %%
list1 = []

for gen in movies.Genre.cat.categories: 
    list1.append(movies[movies.Genre==gen].BudgetMillions) 
    mylabels.append(gen)
sns.set_style("whitegrid") 
fig, ax = plt.subplots()
fig.set_size_inches(11.7,8.24) #size of A4 paper

h = plt.hist(list1,bins=30, stacked=True,rwidth=1,label=mylabels)
 
plt.title("Movie Budget Distribution",fontsize=35, color="DarkBlue", fontname="Console") 
plt.ylabel("Number of Movies",fontsize=25,color="Red") 
plt.xlabel("Budget",fontsize=25,color="Green")
plt.legend(frameon=True,prop={'size':20}) 
plt.show()

# %%
list1 = []

for gen in movies.Genre.cat.categories: 
    list1.append(movies[movies.Genre==gen].BudgetMillions) 
    mylabels.append(gen)
sns.set_style("whitegrid") 
fig, ax = plt.subplots()
fig.set_size_inches(11.7,8.24) #size of A4 paper

h = plt.hist(list1,bins=30, stacked=True,rwidth=1,label=mylabels) 
plt.title("Movie Budget Distribution",fontsize=35,color="DarkBlue", fontname="Console") 
plt.ylabel("Number of Movies",fontsize=25,color="Red") 
plt.xlabel("Budget",fontsize=25,color="Green") 
plt.legend(frameon=True,framealpha=0.5,prop={'size':20})
plt.show()

# %%
# Dashboard
# First Academia

# %%
sns.set_style("darkgrid")
f, axes = plt.subplots(2,2, figsize=(15,15))

k1 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRating,ax=axes[0,0]) 
k2 = sns.kdeplot(movies.BudgetMillions,movies.CriticRating,ax=axes[0,1])
z = sns.violinplot(data=movies[movies.Genre=='Drama'],x='Year',y='CriticRating',ax=axes[1,0]) 
k4 = sns.kdeplot(movies.CriticRating,movies.AudienceRating,shade=True, shade_lowest=False, cmap='Reds', ax=axes[1,1])
k4b = sns.kdeplot(movies.CriticRating,movies.AudienceRating,cmap='Reds', ax=axes[1,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160)) 
plt.show()

# %%
#Conference 
sns.set_style("dark",{"axes.facecolor":"black"}) 
f, axes = plt.subplots(2,2, figsize=(15,15))
k1 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRating,shade=True, shade_lowest=True, cmap='inferno',ax=axes[0,0])
k1b = sns.kdeplot(movies.BudgetMillions,movies.AudienceRating,cmap='cool',  ax=axes[0,0])
k2 = sns.kdeplot(movies.BudgetMillions,movies.CriticRating,shade=True, shade_lowest=True, cmap='inferno',ax=axes[0,1])
k2b = sns.kdeplot(movies.BudgetMillions,movies.CriticRating,cmap='cool', ax=axes[0,1]) 
z = sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year',y='CriticRating',ax=axes[1,0],palette='YlOrRd')
k4 = sns.kdeplot(movies.CriticRating,movies.AudienceRating,shade=True, shade_lowest=False, cmap='Blues_r', ax=axes[1,1])
k4b = sns.kdeplot(movies.CriticRating,movies.AudienceRating,cmap='gist_gray_r', ax=axes[1,1])

k1.set(xlim=(-20,160))

k2.set(xlim=(-20,160))
plt.show()

# %%
print('ended')
# Out:
# ended

# %%
#over movie case
